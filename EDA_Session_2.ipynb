# %% [markdown]
# - We Created a data frame using list
#
# - provided data
#
# - Columns
#
# - index added
#
# - Modified the column
#
# - Drop the column
#
# - shape of the data frame
#
# - How to save the data frame

# %% [markdown]
# **How to read a data frame**

# %% [markdown]
# - location
#
# - file name
#
# - extention
#
# - I want to read data1
#
# - location is not required because python file and data file both are the same location
#
# - file name: data 1
#
# - extention: .CSV

# %%
import pandas as pd

# %%
pd.read_csv('data1.csv')
# Out:
#    Names  Age     City
# 0  Akash   35  chennai
# 1   Anvi   40   Mumbai

# %%
pd.read_csv('data.csv')
# Out:
#   Unnamed: 0  Names  Age     City
# 0          C  Akash   35  chennai
# 1          D   Anvi   40   Mumbai

# %%
pd.read_excel('data2.xlsx')
# Out:
#    Names  Age     City
# 0  Akash   35  chennai
# 1   Anvi   40   Mumbai

# %% [markdown]
# $task$

# %% [markdown]
# - Download visadataset and bank
# - save in a local folder
# - Read here
# - First visa data set
# - Second bank

# %%
visa_df=pd.read_csv(r"C:\Users\dell\Documents\EDA_python\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
bank_df=pd.read_csv(r"C:\Users\dell\Documents\EDA_python\bank.csv")
bank_df
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %% [markdown]
# **Create data frame using dictionary**

# %%
name=['Avinash','Aakash','Aadhya']
age=[25,30,35]
pd.DataFrame(zip(name,age),columns=['Name','Ages'])
# Out:
#       Name  Ages
# 0  Avinash    25
# 1   Aakash    30
# 2   Aadhya    35

# %%
dict1={'Names':['Avinash','Aakash','Aadhya'],
       'Ages':[25,30,35]}
dict1
# Out:
# {'Names': ['Avinash', 'Aakash', 'Aadhya'], 'Ages': [25, 30, 35]}

# %%
pd.DataFrame(dict1)
#keys becomes columns
# values becomes rows
# No need to provide columns names separately
# Out:
#      Names  Ages
# 0  Avinash    25
# 1   Aakash    30
# 2   Aadhya    35

# %%
dict2={'Names':'Avinash',
       'Ages':25,
       'City':'Hyd'}
pd.DataFrame(dict2,index=[1,2,3])
# Out:
#      Names  Ages City
# 1  Avinash    25  Hyd
# 2  Avinash    25  Hyd
# 3  Avinash    25  Hyd

# %%
visa_df=pd.read_csv(r"C:\Users\dell\Documents\EDA_python\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]
